# %%
import numpy as np

# %%
f = lambda x: np.sin(x)
f_1 = lambda x: np.cos(x)

# %%
f(1)
# Out:
# 0.8414709848078965

# %%
f_1(1)
# Out:
# 0.5403023058681398

# %%
f_1(1) - ((f(1.1) - f(1)) / 0.1)
# Out:
# 0.04293855333275065

# %%
(1/2)*(f(1))*(0.1**2)
# Out:
# 0.004207354924039484

# %%
true = np.cos(1)

# %%
est = (np.sin(1.1) - np.sin(1))/0.1

# %%
print(true,est,true-est)
# Out:
# 0.5403023058681398 0.4973637525353891 0.04293855333275065

# %%
1/2*np.sin(1)*0.1
# Out:
# 0.04207354924039483

# %%
np.cos(1) - (np.sin(1.1) - np.sin(0.9))/0.2
# Out:
# -0.04113844593599114
