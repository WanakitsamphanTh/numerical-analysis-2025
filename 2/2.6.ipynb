# %%
import numpy as np
from functools import reduce

def simpson(f,h,a,b):
    N = int((b - a) / h)
    S = 0

    for i in range(1,N,2):
        xs = [a + (i-1) * h, a + i * h, a + (i+1) * h]
        S = S + h / 3 * (f(xs[0]) + 4 * f(xs[1]) + f(xs[2]))
        if xs[2] % 100 == 0: yield S

# %%
a = 0
b = 10000
h = 1e-4

def f(x):
    if x == 0: return 1
    return np.sin(x) / x

bs = [100 + x for x in range(0,b,100)]
simpson_y_6 = np.fromiter(simpson(f,h,a,b),dtype='float64')

y = np.pi / 2

simpson_err = np.abs(y - simpson_y)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.set_xscale('log',base=10)
ax.set_yscale('log',base=10)
ax.set_xlabel("h")
ax.set_ylabel("Error [T-M]")
ax.plot(bs,simpson_err,linestyle='--',color='grey')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.set_xscale('log',base=10)
#ax.set_yscale('log',base=10)
ax.set_xlabel("h")
ax.set_ylabel("Error [T-M]")
ax.plot(bs,daikei_y,linestyle='solid',color='black')
ax.plot(bs,simpson_y,linestyle='--',color='grey')
ax.legend(['trapezoid','simpson'])
