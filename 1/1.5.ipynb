# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
errors = pd.read_csv("./errors.csv",delimiter='\t',header=None,names = ["i","float","double"])
print(errors)
# Out:
#          i     float        double
# 0       10  0.000003  1.665335e-16
# 1       20  0.000003  3.330669e-16
# 2       30  0.000004  1.165734e-15
# 3       40  0.000005  1.554312e-15
# 4       50  0.000006  2.053913e-15
# ..     ...       ...           ...
# 995   9960  0.096130  1.579901e-10
# 996   9970  0.096375  1.582177e-10
# 997   9980  0.096619  1.584453e-10
# 998   9990  0.096863  1.586729e-10
# 999  10000  0.097107  1.589004e-10
#
# [1000 rows x 3 columns]

# %%
fig, ax = plt.subplots()
ax.set_xlim(10,10000)
ax.set_ylim(10**-18,1)
ax.set_xscale('log',base=10)
ax.set_yscale('log',base=10)
ax.set_xlabel('Number of Iterations')
ax.set_ylabel('Absolute Error')
ax.plot(errors['i'],(errors["float"]),linestyle='solid',color='black')
ax.plot(errors['i'],(errors["double"]),linestyle='dotted', color='black')
ax.legend(['float','double'])
